# %%
import json
import click
import re
import nltk
from nltk.corpus import wordnet as wn
from textblob import TextBlob

# %%
class Article:
    def __init__(self, title):
        self.title = title
        fp = open(title, mode="r")
        self.summary = fp.read()
        fp.close()

    def generate_trivia_sentences(self):
        sentences = nltk.sent_tokenize(self.summary)

        # Remove the first sentence - it's never a good one
        # del sentences[0] just kidding

        trivia_sentences = []
        for sentence in sentences:
            trivia = self.evaluate_sentence(sentence)
            if trivia:
                trivia_sentences.append(trivia)

        return trivia_sentences


    def get_similar_words(self, word):
        # In the absence of a better method, take the first synset
        synsets = wn.synsets(word, pos='n')

        # If there aren't any synsets, return an empty list
        if len(synsets) == 0:
            return []
        else:
            synset = synsets[0]

        # Get the hypernym for this synset (again, take the first)
        hypernym = synset.hypernyms()[0]

        # Get some hyponyms from this hypernym
        hyponyms = hypernym.hyponyms()

        # Take the name of the first lemma for the first 8 hyponyms
        similar_words = []
        for hyponym in hyponyms:
            similar_word = hyponym.lemmas()[0].name().replace('_', ' ')
            
            if similar_word != word:
                similar_words.append(similar_word)

            if len(similar_words) == 8:
                break

        return similar_words


    def evaluate_sentence(self, sentence):
        # if sentence starts with an adverb or is less than 4 words long
        # probably not the best fit
        tags = nltk.pos_tag(sentence)
        if tags[0][1] == 'RB' or len(nltk.word_tokenize(sentence)) < 4:
            return None

        tag_map = {word.lower(): tag for word, tag in tags}

        # extract noun phrases from the sentence
        noun_phrases = list()
        grammar1 = r""" CHUNK: {<NN.*|JJ>*<NN.*>} """
        grammar2 = r"""
            CHUNK: {<NN>+<IN|DT>*<NN>+}
                {<NN>+<IN|DT>*<NNP>+}
                {<NNP>+<NNS>*}
            """
        chunker = nltk.RegexpParser(grammar2)
        tokens = nltk.word_tokenize(sentence)
        pos_tokens = nltk.tag.pos_tag(tokens)
        tree = chunker.parse(pos_tokens)

        # select phrase
        for subtree in tree.subtrees():
            if subtree.label() == "CHUNK":
                temp = ""
                for sub in subtree:
                    temp += sub[0]
                    temp += " "
                temp = temp.strip() # strip extra whitespace
                noun_phrases.append(temp)
        
        # replace nouns
        replace_nouns = []
        for word, tag in tags:
            for phrase in noun_phrases:
                if phrase[0] == '\'':
                    # If it starts with an apostrophe, ignore it
                    # (this is a weird error that should probably
                    # be handled elsewhere)
                    break
                if word in phrase:
                    # Blank out the last two words in this phrase
                    [replace_nouns.append(phrase_word) for phrase_word in phrase.split()[-2:]]
                    break
            # If we couldn't find the word in any phrases,
            # replace it on its own
            if len(replace_nouns) == 0:
                replace_nouns.append(word)
            break
        
        if len(replace_nouns) == 0:
            # Return none if we found no words to replace
            return None
        val = 99
        for i in replace_nouns:
            if len(i) < val:
                val = len(i)  

        trivia = {
            "answer": " ".join(replace_nouns),
            "anser_key": val
        }

        if len(replace_nouns) == 1:
            # If we're only replacing one word, use WordNet to find similar words
            trivia['similar_words'] = self.get_similar_words(replace_nouns[0])
        else:
            # If we're replacing a phrase, don't bother - it's too unlikely to make sense
            trivia['similar_words'] = []

        # Blank out our replace words (only the first occurrence of the word in the sentence)
        replace_phrase = ' '.join(replace_nouns)
        blanks_phrase = ('__________ ' * len(replace_nouns)).strip()

        expression = re.compile(re.escape(replace_phrase), re.IGNORECASE)
        sentence = expression.sub(blanks_phrase, str(sentence), count=1)

        trivia['question'] = sentence
        return trivia

# %%
def generate_trivia():
    # Retrieve the trivia sentences
    questions = list()
    # create an object
    filename = "data/dbms.txt"
    obj_a = Article(filename)
    # call method on the object
    questions.append(obj_a.generate_trivia_sentences())
    return questions
    # with open('data.txt', 'w') as outfile:
        # json.dump(questions, outfile)

# %%
questions_generated = generate_trivia()

# %%
questions_generated
# Out:
# [[{'anser_key': 8,
#    'answer': 'Database',
#    'question': '__________ is a collection of related data and data is a collection of facts and figures\nthat can be processed to produce information.',
#    'similar_words': ['ammunition',
#     'confirmation',
#     'course of study',
#     'database',
#     'details',
#     'evidence',
#     'fact',
#     'factoid']},
#   {'anser_key': 1,
#    'answer': 'M',
#    'question': '__________ostly data represents recordable facts.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 4,
#    'answer': 'Data aids',
#    'question': '__________ __________ in producing information, which is\nbased on facts.',
#    'similar_words': []},
#   {'anser_key': 1,
#    'answer': 'F',
#    'question': '__________or example, if we have data about marks obtained by all students,\nwe can then conclude about toppers and average marks.',
#    'similar_words': ['degree centigrade', 'degree Fahrenheit']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________ database management system stores data in such a way that it becomes easier\nto retrieve, manipulate, and produce information.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________raditionally, data was organized in file formats.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 4,
#    'answer': 'DBMS',
#    'question': '__________ was a new concept then, and\nall the research was done to make it overcome the deficiencies in traditional style of\ndata management.',
#    'similar_words': ['alpha software',
#     'authoring language',
#     'beta software',
#     'compatible software',
#     'compatible software',
#     'computer-aided design',
#     'database management system',
#     'freeware']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________ modern DBMS has the following characteristics:\n1.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 1,
#    'answer': 'R',
#    'question': '__________eal-world entity: A modern DBMS is more realistic and uses real-world\nentities to design its architecture.',
#    'similar_words': ['curie',
#     'gray',
#     'millicurie',
#     'rad',
#     'REM',
#     'roentgen',
#     'rutherford']},
#   {'anser_key': 1,
#    'answer': 'I',
#    'question': '__________t uses the behavior and attributes too.',
#    'similar_words': ['actinium',
#     'allotrope',
#     'argon',
#     'arsenic',
#     'astatine',
#     'bohrium',
#     'boron',
#     'bromine']},
#   {'anser_key': 1,
#    'answer': 'F',
#    'question': '__________or\nexample, a school database may use students as an entity and their age as an\nattribute.',
#    'similar_words': ['degree centigrade', 'degree Fahrenheit']},
#   {'anser_key': 1,
#    'answer': '2',
#    'question': '__________.Relation-based tables: DBMS allows entities and relations among them to\nform tables.',
#    'similar_words': ['binary digit',
#     'decimal digit',
#     'duodecimal digit',
#     'eight',
#     'five',
#     'four',
#     'hexadecimal digit',
#     'nine']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________ user can understand the architecture of a database just by\nlooking at the table names.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 1,
#    'answer': 'I',
#    'question': '__________solation of data and application: A database system is entirely different\nthan its data.',
#    'similar_words': ['actinium',
#     'allotrope',
#     'argon',
#     'arsenic',
#     'astatine',
#     'bohrium',
#     'boron',
#     'bromine']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________ database is an active entity, whereas data is said to be passive,\non which the database works and organizes.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 4,
#    'answer': 'DBMS',
#    'question': '__________ also stores metadata, which\nis data about data, to ease its own process.',
#    'similar_words': ['alpha software',
#     'authoring language',
#     'beta software',
#     'compatible software',
#     'compatible software',
#     'computer-aided design',
#     'database management system',
#     'freeware']},
#   {'anser_key': 4,
#    'answer': 'Less',
#    'question': '__________ redundancy: DBMS follows the rules of normalization, which splits a\nrelation when any of its attributes is having redundancy in values.',
#    'similar_words': ['ankylosing spondylitis',
#     'discoid lupus erythematosus',
#     "Graves' disease",
#     "Hashimoto's disease",
#     'lupus erythematosus',
#     'multiple sclerosis',
#     'myasthenia gravis',
#     'pemphigus']},
#   {'anser_key': 1,
#    'answer': 'N',
#    'question': '__________ormalization is a mathematically rich and scientific process that reduces data\nredundancy.',
#    'similar_words': ['actinium',
#     'allotrope',
#     'argon',
#     'arsenic',
#     'astatine',
#     'bohrium',
#     'boron',
#     'bromine']},
#   {'anser_key': 1,
#    'answer': 'C',
#    'question': '__________onsistency: Consistency is a state where every relation in a database\nremains consistent.',
#    'similar_words': ['degree centigrade', 'degree Fahrenheit']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________here exist methods and techniques, which can detect\nattempt of leaving database in inconsistent state.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________ DBMS can provide greater consistency as compared to earlier forms of data storing applications like file-\nprocessing systems.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 1,
#    'answer': 'Q',
#    'question': '__________uery Language: DBMS is equipped with query language, which makes it\nmore efficient to retrieve and manipulate data.',
#    'similar_words': ['A',
#     'aleph',
#     'alpha',
#     'ascender',
#     'ayin',
#     'B',
#     'beta',
#     'beth']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________ user can apply as many and\nas different filtering options as required to retrieve a set of data.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________raditionally\nit was not possible where file-processing system was used.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 4,
#    'answer': 'ACID Properties',
#    'question': '__________ __________: DBMS follows the concepts of Atomicity, Consistency,\nIsolation, and Durability (normally shortened as ACID).',
#    'similar_words': []},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________hese concepts are\napplied on transactions, which manipulate data in a database.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 4,
#    'answer': 'ACID properties',
#    'question': '__________ __________\nhelp the database stay healthy in multi-transactional environments and in case\nof failure.',
#    'similar_words': []},
#   {'anser_key': 9,
#    'answer': 'Multiuser',
#    'question': '__________ and Concurrent Access: DBMS supports multi-user environment\nand allows them to access and manipulate data in parallel.',
#    'similar_words': []},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________hough there are\nrestrictions on transactions when users attempt to handle the same data item,\nbut users are always unaware of them.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 4,
#    'answer': 'DBMS',
#    'question': 'Multiple views: __________ offers multiple views for different users.',
#    'similar_words': ['alpha software',
#     'authoring language',
#     'beta software',
#     'compatible software',
#     'compatible software',
#     'computer-aided design',
#     'database management system',
#     'freeware']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________ user who is\nin the Sales department will have a different view of database than a person\nworking in the Production department.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________his feature enables the users to have\na concentrate view of the database according to their requirements.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 1,
#    'answer': 'S',
#    'question': '__________ecurity: Features like multiple views offer security to some extent where\nusers are unable to access data of other users and departments.',
#    'similar_words': ['attosecond',
#     'bell',
#     'day',
#     'femtosecond',
#     'half-hour',
#     'hour',
#     'mean time',
#     'microsecond']},
#   {'anser_key': 4,
#    'answer': 'DBMS',
#    'question': '__________ offers\nmethods to impose constraints while entering data into the database and\nretrieving the same at a later stage.',
#    'similar_words': ['alpha software',
#     'authoring language',
#     'beta software',
#     'compatible software',
#     'compatible software',
#     'computer-aided design',
#     'database management system',
#     'freeware']},
#   {'anser_key': 4,
#    'answer': 'DBMS',
#    'question': '__________ offers many different levels of\nsecurity features, which enables multiple users to have different views with\ndifferent features.',
#    'similar_words': ['alpha software',
#     'authoring language',
#     'beta software',
#     'compatible software',
#     'compatible software',
#     'computer-aided design',
#     'database management system',
#     'freeware']},
#   {'anser_key': 1,
#    'answer': 'F',
#    'question': '__________or example, a user in the Sales department cannot see the\ndata that belongs to the Purchase department.',
#    'similar_words': ['degree centigrade', 'degree Fahrenheit']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________dditionally, it can also be\nmanaged how much data of the Sales department should be displayed to the\nuser.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 4,
#    'answer': 'DBMS',
#    'question': 'Since a __________ is not saved on the disk as traditional file systems, it is\nvery hard for miscreants to break the code.',
#    'similar_words': ['alpha software',
#     'authoring language',
#     'beta software',
#     'compatible software',
#     'compatible software',
#     'computer-aided design',
#     'database management system',
#     'freeware']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________ typical DBMS has users with different rights and permissions who use it for different purposes.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 1,
#    'answer': 'S',
#    'question': '__________ome users retrieve data and some back it up.',
#    'similar_words': ['attosecond',
#     'bell',
#     'day',
#     'femtosecond',
#     'half-hour',
#     'hour',
#     'mean time',
#     'microsecond']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________he users of a DBMS can\nbe broadly categorized as follows:\n1.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________dministrators: Administrators maintain the DBMS and are responsible for\nadministrating the database.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________hey are responsible to look after its usage and\nby whom it should be used.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________hey create access profiles for users and apply\nlimitations to maintain isolation and force security.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________dministrators also look\nafter DBMS resources like system license, required tools, and other software\nand hardware related maintenance.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']},
#   {'anser_key': 1,
#    'answer': 'D',
#    'question': '__________esigners: Designers are the group of people who actually work on the\ndesigning part of the database.',
#    'similar_words': ['vitamin A', 'vitamin D', 'vitamin E', 'vitamin K']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________hey keep a close watch on what data should\nbe kept and in what format.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________hey identify and design the whole set of entities,\nrelations, constraints, and views.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 1,
#    'answer': 'E',
#    'question': '__________nd Users: End users are those who actually reap the benefits of having a\nDBMS.',
#    'similar_words': ['beta-naphthol',
#     'carotenoid',
#     'glutathione peroxidase',
#     'rust inhibitor',
#     'selenium',
#     'vitamin C',
#     'vitamin E']},
#   {'anser_key': 1,
#    'answer': 'E',
#    'question': '__________nd users can range from simple viewers who pay attention to the logs\nor market rates to sophisticated users such as business analysts.',
#    'similar_words': ['beta-naphthol',
#     'carotenoid',
#     'glutathione peroxidase',
#     'rust inhibitor',
#     'selenium',
#     'vitamin C',
#     'vitamin E']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________he design of a DBMS depends on its architecture.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 1,
#    'answer': 'I',
#    'question': '__________t can be centralized or\ndecentralized or hierarchical.',
#    'similar_words': ['actinium',
#     'allotrope',
#     'argon',
#     'arsenic',
#     'astatine',
#     'bohrium',
#     'boron',
#     'bromine']},
#   {'anser_key': 1,
#    'answer': 'T',
#    'question': '__________he architecture of a DBMS can be seen as either single\ntier or multi-tier.',
#    'similar_words': ['cytosine', 'thymine']},
#   {'anser_key': 1,
#    'answer': 'A',
#    'question': '__________n n-tier architecture divides the whole system into related but\nindependent n modules, which can be independently modified, altered, changed, or\nreplaced.',
#    'similar_words': ['angstrom',
#     'centimeter',
#     'decameter',
#     'decimeter',
#     'femtometer',
#     'hectometer',
#     'kilometer',
#     'meter']}]]

# %%
que_ans_pair = list()
for lis in questions_generated:
    for que in lis:
        if que["anser_key"] > 4:
            que_ans_pair.append(que)
        else:
            continue

# %%
que_ans_pair
# Out:
# [{'anser_key': 8,
#   'answer': 'Database',
#   'question': '__________ is a collection of related data and data is a collection of facts and figures\nthat can be processed to produce information.',
#   'similar_words': ['ammunition',
#    'confirmation',
#    'course of study',
#    'database',
#    'details',
#    'evidence',
#    'fact',
#    'factoid']},
#  {'anser_key': 9,
#   'answer': 'Multiuser',
#   'question': '__________ and Concurrent Access: DBMS supports multi-user environment\nand allows them to access and manipulate data in parallel.',
#   'similar_words': []}]

# %%
que_ans_pair[0]
# Out:
# {'anser_key': 8,
#  'answer': 'Database',
#  'question': '__________ is a collection of related data and data is a collection of facts and figures\nthat can be processed to produce information.',
#  'similar_words': ['ammunition',
#   'confirmation',
#   'course of study',
#   'database',
#   'details',
#   'evidence',
#   'fact',
#   'factoid']}

# %%
que_ans_pair[1]
# Out:
# {'anser_key': 9,
#  'answer': 'Multiuser',
#  'question': '__________ and Concurrent Access: DBMS supports multi-user environment\nand allows them to access and manipulate data in parallel.',
#  'similar_words': []}

# %%
len(que_ans_pair)
# Out:
# 2

# %%
import numpy as np
for x in range(3):
    rand_num = np.random.randint(0, len(que_ans_pair))
    print(que_ans_pair[rand_num]["question"])
    print(que_ans_pair[rand_num]["answer"])
    print()
# Out:
# __________ and Concurrent Access: DBMS supports multi-user environment
# and allows them to access and manipulate data in parallel.
# Multiuser
#
# __________ and Concurrent Access: DBMS supports multi-user environment
# and allows them to access and manipulate data in parallel.
# Multiuser
#
# __________ is a collection of related data and data is a collection of facts and figures
# that can be processed to produce information.
# Database

# %%
for x in que_ans_pair:
    #print(x["question"])
    que = x["question"]
    mlist = [x for x in que.split(" ")]
    #print(mlist)
    strr = ""
    new_list = list()
    if mlist[1] in ["is", "are"]:
        for y in mlist:
            if y != "__________":
                new_list.append(y)
        strr = " ".join(new_list)
        strr = "What " + strr
        print(strr)
# Out:
# What is a collection of related data and data is a collection of facts and figures
# that can be processed to produce information.
