# %%
# import packages
import pandas as pd
import numpy as np

# %%
# load the data to dataframe
df = pd.read_csv("data/global_terrorism_dataset.csv", header=0)
print("Dataset Size: [row, col]", df.shape)
df.head()
# Out:
# Dataset Size: [row, col] (129922, 31)
#         eventid  iyear  imonth  iday   latitude   longitude  extended  \
# 0  197000000001   1970       7     2  18.456792  -69.951164         0
# 1  197000000002   1970       0     0  19.432608  -99.133207         0
# 2  197001000001   1970       1     0  15.478598  120.599741         0
# 3  197001000002   1970       1     0  37.983773   23.728157         0
# 4  197001010002   1970       1     1  37.005105  -89.176269         0
#
#    vicinity  crit1  crit2       ...        region  \
# 0         0      1      1       ...             2
# 1         0      1      1       ...             1
# 2         0      1      1       ...             5
# 3         0      1      1       ...             8
# 4         0      1      1       ...             1
#
#                     region_txt              attacktype1_txt  \
# 0  Central America & Caribbean                Assassination
# 1                North America  Hostage Taking (Kidnapping)
# 2               Southeast Asia                Assassination
# 3               Western Europe            Bombing/Explosion
# 4                North America                Armed Assault
#
#                  targtype1_txt         natlty1_txt              weaptype1_txt  \
# 0  Private Citizens & Property  Dominican Republic                    Unknown
# 1      Government (Diplomatic)             Belgium                    Unknown
# 2          Journalists & Media       United States                    Unknown
# 3      Government (Diplomatic)       United States  Explosives/Bombs/Dynamite
# 4                       Police       United States                   Firearms
#
#                      target1                               gname  ncasualties  \
# 0               julio guzman                              mano-d            1
# 1    nadine chaval, daughter  23rd of september communist league            0
# 2                   employee                             unknown            1
# 3               u.s. embassy                             unknown            0
# 4  cairo police headquarters                  black nationalists            0
#
#    has_casualties
# 0               1
# 1               0
# 2               1
# 3               0
# 4               0
#
# [5 rows x 31 columns]

# %%
# check column names
column_names = df.columns
column_names
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'latitude', 'longitude',
#        'extended', 'vicinity', 'crit1', 'crit2', 'crit3', 'doubtterr',
#        'multiple', 'success', 'suicide', 'claimed', 'property', 'ishostkid',
#        'nkill', 'nwound', 'country_txt', 'region', 'region_txt',
#        'attacktype1_txt', 'targtype1_txt', 'natlty1_txt', 'weaptype1_txt',
#        'target1', 'gname', 'ncasualties', 'has_casualties'],
#       dtype='object')

# %%
# check for null or missing values
df.isnull().sum()
# Out:
# eventid                0
# iyear                  0
# imonth                 0
# iday                   0
# latitude            2867
# longitude           2867
# extended               0
# vicinity               0
# crit1                  0
# crit2                  0
# crit3                  0
# doubtterr              0
# multiple               0
# success                0
# suicide                0
# claimed            42068
# property               0
# ishostkid            161
# nkill                  0
# nwound                 0
# country_txt            0
# region                 0
# region_txt             0
# attacktype1_txt        0
# targtype1_txt          0
# natlty1_txt         1164
# weaptype1_txt          0
# target1                0
# gname                  0
# ncasualties            0
# has_casualties         0
# dtype: int64

# %%
# remove useless columns
remove_columns = [
    "iyear", "iday", "latitude", "longitude", "claimed",
    "ishostkid", "natlty1_txt", "region", "gname", "extended",
    "eventid", "crit1", "crit2", "crit3", "weaptype1_txt", "doubtterr", "suicide",
    "property", "has_casualties", "vicinity", "multiple", "nkill", "nwound", "success"]
selected_columns = [x for x in column_names if x not in remove_columns]
# select a slice of the dataframe to work further
df = df[selected_columns]
df.head()
# Out:
#    imonth         country_txt                   region_txt  \
# 0       7  Dominican Republic  Central America & Caribbean
# 1       0              Mexico                North America
# 2       1         Philippines               Southeast Asia
# 3       1              Greece               Western Europe
# 4       1       United States                North America
#
#                attacktype1_txt                targtype1_txt  \
# 0                Assassination  Private Citizens & Property
# 1  Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                Assassination          Journalists & Media
# 3            Bombing/Explosion      Government (Diplomatic)
# 4                Armed Assault                       Police
#
#                      target1  ncasualties
# 0               julio guzman            1
# 1    nadine chaval, daughter            0
# 2                   employee            1
# 3               u.s. embassy            0
# 4  cairo police headquarters            0

# %%
# re check for null or anh missing values
df.isnull().sum()
# Out:
# imonth             0
# country_txt        0
# region_txt         0
# attacktype1_txt    0
# targtype1_txt      0
# target1            0
# ncasualties        0
# dtype: int64

# %%
# let's work around with the object data type col
object_type_columns = [x for x in selected_columns if df[x].dtypes == "object"]
object_type_columns
# Out:
# ['country_txt', 'region_txt', 'attacktype1_txt', 'targtype1_txt', 'target1']

# %%
# encoding str columns to categorical columns by encoding it
from sklearn.preprocessing import LabelEncoder

labler = LabelEncoder()

# encode each str type col to int
for x in object_type_columns:
    new_name = x + "_code"
    df[new_name] = labler.fit_transform(df[x])
    df[new_name] = df[new_name].astype("category")
df.head()
# Out:
#    imonth         country_txt                   region_txt  \
# 0       7  Dominican Republic  Central America & Caribbean
# 1       0              Mexico                North America
# 2       1         Philippines               Southeast Asia
# 3       1              Greece               Western Europe
# 4       1       United States                North America
#
#                attacktype1_txt                targtype1_txt  \
# 0                Assassination  Private Citizens & Property
# 1  Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                Assassination          Journalists & Media
# 3            Bombing/Explosion      Government (Diplomatic)
# 4                Armed Assault                       Police
#
#                      target1  ncasualties country_txt_code region_txt_code  \
# 0               julio guzman            1               45               1
# 1    nadine chaval, daughter            0              114               6
# 2                   employee            1              137               9
# 3               u.s. embassy            0               66              11
# 4  cairo police headquarters            0              186               6
#
#   attacktype1_txt_code targtype1_txt_code target1_code
# 0                    1                 13        31401
# 1                    6                  5        37488
# 2                    1                  7        21436
# 3                    2                  5        60318
# 4                    0                 12        11810

# %%
dff = df[["imonth", "country_txt", "region_txt", "target1", "ncasualties", "targtype1_txt", "attacktype1_txt"]].copy()
dff.head()
# Out:
#    imonth         country_txt                   region_txt  \
# 0       7  Dominican Republic  Central America & Caribbean
# 1       0              Mexico                North America
# 2       1         Philippines               Southeast Asia
# 3       1              Greece               Western Europe
# 4       1       United States                North America
#
#                      target1  ncasualties                targtype1_txt  \
# 0               julio guzman            1  Private Citizens & Property
# 1    nadine chaval, daughter            0      Government (Diplomatic)
# 2                   employee            1          Journalists & Media
# 3               u.s. embassy            0      Government (Diplomatic)
# 4  cairo police headquarters            0                       Police
#
#                attacktype1_txt
# 0                Assassination
# 1  Hostage Taking (Kidnapping)
# 2                Assassination
# 3            Bombing/Explosion
# 4                Armed Assault

# %%
dff.to_csv("data/testing-again-for-satisfaction.csv", index=True)

# %%
dff
# Out:
#         imonth                       country_txt                   region_txt  \
# 0            7                Dominican Republic  Central America & Caribbean
# 1            0                            Mexico                North America
# 2            1                       Philippines               Southeast Asia
# 3            1                            Greece               Western Europe
# 4            1                     United States                North America
# 5            1                           Uruguay                South America
# 6            1                     United States                North America
# 7            1                     United States                North America
# 8            1                     United States                North America
# 9            1                East Germany (GDR)               Eastern Europe
# 10           1                     United States                North America
# 11           1                     United States                North America
# 12           1                     United States                North America
# 13           1                     United States                North America
# 14           1                           Uruguay                South America
# 15           1                     United States                North America
# 16           1                     United States                North America
# 17           1                     United States                North America
# 18           1                         Guatemala  Central America & Caribbean
# 19           1                       Philippines               Southeast Asia
# 20           1                         Venezuela                South America
# 21           1                     United States                North America
# 22           1                     United States                North America
# 23           1                     United States                North America
# 24           1                     United States                North America
# 25           1                     United States                North America
# 26           1                     United States                North America
# 27           1                     United States                North America
# 28           1                     United States                North America
# 29           2                     United States                North America
# ...        ...                               ...                          ...
# 129892      12                              Iraq   Middle East & North Africa
# 129893      12                           Nigeria           Sub-Saharan Africa
# 129894      12                           Nigeria           Sub-Saharan Africa
# 129895      12                       Philippines               Southeast Asia
# 129896      12                       Afghanistan                   South Asia
# 129897      12                             India                   South Asia
# 129898      12                          Pakistan                   South Asia
# 129899      12                       Afghanistan                   South Asia
# 129900      12                       Afghanistan                   South Asia
# 129901      12                       Afghanistan                   South Asia
# 129902      12                             Egypt   Middle East & North Africa
# 129903      12                       Philippines               Southeast Asia
# 129904      12                        Bangladesh                   South Asia
# 129905      12                          Pakistan                   South Asia
# 129906      12                       Afghanistan                   South Asia
# 129907      12                           Burundi           Sub-Saharan Africa
# 129908      12                          Pakistan                   South Asia
# 129909      12                             India                   South Asia
# 129910      12                       Afghanistan                   South Asia
# 129911      12                           Nigeria           Sub-Saharan Africa
# 129912      12                              Iraq   Middle East & North Africa
# 129913      12                              Iraq   Middle East & North Africa
# 129914      12                              Iraq   Middle East & North Africa
# 129915      12                              Iraq   Middle East & North Africa
# 129916      12                              Iraq   Middle East & North Africa
# 129917      12                          Pakistan                   South Asia
# 129918      12                       Afghanistan                   South Asia
# 129919      12                       Afghanistan                   South Asia
# 129920      12                       Philippines               Southeast Asia
# 129921      12  Democratic Republic of the Congo           Sub-Saharan Africa
#
#                                                   target1  ncasualties  \
# 0                                            julio guzman            1
# 1                                 nadine chaval, daughter            0
# 2                                                employee            1
# 3                                            u.s. embassy            0
# 4                               cairo police headquarters            0
# 5       juan maria de lucah/chief of directorate of in...            0
# 6       r.o.t.c. offices at university of wisconsin, m...            0
# 7       selective service headquarters in madison wisc...            0
# 8         packard properties building of detroit michigan            0
# 9                      jurists ball (palais au frankturm)            0
# 10                              james madison high school            0
# 11      general electric factory in rio grande puerto ...            0
# 12           fuson's department store, seattle washington            0
# 13                            champaign police department            1
# 14                        secondary school, chemistry lab            0
# 15      liberal arts and garrand buildings, seattle un...            0
# 16      air force r.o.t.c. at the university of washin...            0
# 17                                           headquarters            0
# 18                              bodyguard, british consul            1
# 19                                              jusmag hq            0
# 20                                leon jacobo taurel, son            0
# 21                                                unknown            0
# 22      new york police officers responding to a call ...            2
# 23                                 clay county courthouse            0
# 24      new york police officer on patrol in forest hills            0
# 25               selective service office in norwalk ohio            0
# 26                                                unknown            0
# 27                                        a & b boat shop            0
# 28                     army r.o.t.c., university of miami            0
# 29      illinois state police in the pyramid courts ho...            0
# ...                                                   ...          ...
# 129892                                       neighborhood            0
# 129893                                          community            1
# 129894                                          community            1
# 129895                                            unknown            0
# 129896                                           district           21
# 129897                      constable: abdul karim sheikh            1
# 129898                                          civilians            4
# 129899                                            village            1
# 129900                                            village            1
# 129901                                            village            1
# 129902                                            vehicle            3
# 129903                   34th infantry battalion soldiers            1
# 129904         member of parliament: manzurul islam liton            1
# 129905                    vehicle of official: asif mirza            2
# 129906                                            vehicle            6
# 129907                                             church            8
# 129908                  vehicle of leader: rahim barakzai            2
# 129909                  residence of former bank official            0
# 129910                          deputy head: mohammad esa            1
# 129911                                          civilians            3
# 129912                                           district            2
# 129913                                             market           37
# 129914                                             market           36
# 129915                                          civilians            4
# 129916                                          civilians            8
# 129917                                          personnel            2
# 129918                                            vehicle            7
# 129919                                          civilians            7
# 129920                           convoy of relief workers            0
# 129921                                            village            0
#
#                          targtype1_txt                 attacktype1_txt
# 0          Private Citizens & Property                   Assassination
# 1              Government (Diplomatic)     Hostage Taking (Kidnapping)
# 2                  Journalists & Media                   Assassination
# 3              Government (Diplomatic)               Bombing/Explosion
# 4                               Police                   Armed Assault
# 5                               Police                   Assassination
# 6                             Military  Facility/Infrastructure Attack
# 7                 Government (General)  Facility/Infrastructure Attack
# 8                 Government (General)  Facility/Infrastructure Attack
# 9                 Government (General)               Bombing/Explosion
# 10             Educational Institution               Bombing/Explosion
# 11                            Business               Bombing/Explosion
# 12                            Business  Facility/Infrastructure Attack
# 13                              Police  Facility/Infrastructure Attack
# 14             Educational Institution                   Armed Assault
# 15             Educational Institution               Bombing/Explosion
# 16                            Military               Bombing/Explosion
# 17             Violent Political Party  Facility/Infrastructure Attack
# 18             Government (Diplomatic)                   Assassination
# 19             Government (Diplomatic)               Bombing/Explosion
# 20                            Business     Hostage Taking (Kidnapping)
# 21         Private Citizens & Property               Bombing/Explosion
# 22                              Police                   Armed Assault
# 23                Government (General)               Bombing/Explosion
# 24                              Police                   Armed Assault
# 25                Government (General)  Facility/Infrastructure Attack
# 26                             Unknown               Bombing/Explosion
# 27                            Business               Bombing/Explosion
# 28                            Military  Facility/Infrastructure Attack
# 29                              Police                   Armed Assault
# ...                                ...                             ...
# 129892     Private Citizens & Property                         Unknown
# 129893     Private Citizens & Property     Hostage Taking (Kidnapping)
# 129894     Private Citizens & Property     Hostage Taking (Kidnapping)
# 129895                         Unknown               Bombing/Explosion
# 129896     Private Citizens & Property                   Armed Assault
# 129897                          Police                   Armed Assault
# 129898     Private Citizens & Property               Bombing/Explosion
# 129899     Private Citizens & Property                   Armed Assault
# 129900     Private Citizens & Property                   Armed Assault
# 129901     Private Citizens & Property                   Armed Assault
# 129902                          Police               Bombing/Explosion
# 129903                        Military                   Armed Assault
# 129904            Government (General)                   Assassination
# 129905                          Police                   Armed Assault
# 129906     Private Citizens & Property               Bombing/Explosion
# 129907  Religious Figures/Institutions               Bombing/Explosion
# 129908     Private Citizens & Property                   Assassination
# 129909                        Business               Bombing/Explosion
# 129910                          Police                   Armed Assault
# 129911     Private Citizens & Property               Bombing/Explosion
# 129912     Private Citizens & Property               Bombing/Explosion
# 129913     Private Citizens & Property               Bombing/Explosion
# 129914     Private Citizens & Property               Bombing/Explosion
# 129915     Private Citizens & Property               Bombing/Explosion
# 129916     Private Citizens & Property               Bombing/Explosion
# 129917                          Police                   Armed Assault
# 129918    Terrorists/Non-State Militia               Bombing/Explosion
# 129919     Private Citizens & Property               Bombing/Explosion
# 129920                             NGO               Bombing/Explosion
# 129921     Private Citizens & Property     Hostage Taking (Kidnapping)
#
# [129922 rows x 7 columns]

# %%
dff[dff["target1"] == "convoy of relief workers"]
# Out:
#         imonth  country_txt      region_txt                   target1  \
# 129920      12  Philippines  Southeast Asia  convoy of relief workers
#
#         ncasualties targtype1_txt    attacktype1_txt
# 129920            0           NGO  Bombing/Explosion

# %%
# country name mappings with at least 2000 instances
country_names = list()

for x in df["country_txt"].unique():
    if len(df[df["country_txt"] == x]) > 2000:
        country_names.append(x)

# find the encoded value for each of these
for x in country_names:
    for i, row in df.iterrows():
        if row["country_txt"] == x:
            print(x, row["country_txt_code"])
            break
# Out:
# Philippines 137
# United States 186
# Spain 163
# Turkey 180
# United Kingdom 185
# Pakistan 131
# India 78
# France 58
# Colombia 33
# El Salvador 50
# Thailand 176
# Afghanistan 0
# Peru 136
# Somalia 156
# Iraq 82
# Nigeria 128
# Yemen 196

# %%
# region name mappings with at least 100 instances
region_names = list()

for x in df["region_txt"].unique():
    if len(df[df["region_txt"] == x]) > 100:
        region_names.append(x)

# find the encoded value for each of these
for x in region_names:
    for i, row in df.iterrows():
        if row["region_txt"] == x:
            print(x, row["region_txt_code"])
            break
# Out:
# Central America & Caribbean 1
# North America 6
# Southeast Asia 9
# Western Europe 11
# South America 7
# Eastern Europe 4
# Sub-Saharan Africa 10
# Middle East & North Africa 5
# East Asia 3
# Australasia & Oceania 0
# South Asia 8
# Central Asia 2

# %%
# attack type name mappings with at least 100 instances
attack_type_names = list()

for x in df["attacktype1_txt"].unique():
    if len(df[df["attacktype1_txt"] == x]) > 100:
        attack_type_names.append(x)

# find the encoded value for each of these
for x in attack_type_names:
    for i, row in df.iterrows():
        if row["attacktype1_txt"] == x:
            print(x, row["attacktype1_txt_code"])
            break
# Out:
# Assassination 1
# Hostage Taking (Kidnapping) 6
# Bombing/Explosion 2
# Armed Assault 0
# Facility/Infrastructure Attack 3
# Hijacking 4
# Unarmed Assault 7
# Hostage Taking (Barricade Incident) 5
# Unknown 8

# %%
# target type name mappings with at least 100 instances
target_type_names = list()

for x in df["targtype1_txt"].unique():
    if len(df[df["targtype1_txt"] == x]) > 100:
        target_type_names.append(x)

# find the encoded value for each of these
for x in target_type_names:
    for i, row in df.iterrows():
        if row["targtype1_txt"] == x:
            print(x, row["targtype1_txt_code"])
            break
# Out:
# Private Citizens & Property 13
# Government (Diplomatic) 5
# Journalists & Media 7
# Police 12
# Military 9
# Government (General) 6
# Educational Institution 3
# Business 2
# Violent Political Party 21
# Unknown 19
# Transportation 18
# Utilities 20
# Airports & Aircraft 1
# Religious Figures/Institutions 14
# Telecommunication 15
# Food or Water Supply 4
# NGO 10
# Terrorists/Non-State Militia 16
# Other 11
# Tourists 17
# Maritime 8
# Abortion Related 0

# %%
df["targtype1_txt_code"].value_counts()
# Out:
# 13    33890
# 12    20598
# 6     18837
# 2     15206
# 18     5884
# 20     5711
# 19     4501
# 9      4380
# 14     3803
# 3      3798
# 5      2877
# 7      2455
# 16     2134
# 21     1346
# 1      1082
# 15      950
# 10      761
# 11      587
# 17      320
# 8       290
# 4       281
# 0       231
# Name: targtype1_txt_code, dtype: int64

# %%
df["target1"].value_counts()
# Out:
# civilians                                                                         5766
# unknown                                                                           5557
# vehicle                                                                           1720
# checkpoint                                                                        1565
# officers                                                                          1506
# patrol                                                                            1496
# village                                                                           1440
# police station                                                                    1191
# bus                                                                               1119
# market                                                                            1035
# high tension line tower                                                            959
# office                                                                             807
# house                                                                              718
# bank                                                                               632
# soldiers                                                                           608
# town                                                                               575
# mosque                                                                             559
# officer                                                                            501
# civilian                                                                           487
# headquarters                                                                       469
# school                                                                             425
# neighborhood                                                                       413
# convoy                                                                             397
# checkpost                                                                          387
# post                                                                               386
# unit                                                                               376
# members                                                                            374
# restaurant                                                                         374
# building                                                                           364
# shops                                                                              317
#                                                                                   ...
# judge carmen elisa rojas and 3 bodyguards                                            1
# a 30-year-old muslim teacher                                                         1
# 2 story building                                                                     1
# mayor: rodrigo orduna's residence                                                    1
# kidal french camp                                                                    1
# two police officers in shindand district                                             1
# mohammad ismaeil, a presidential campaign official was targeted in the attack.       1
# sarwarzan pilot high school                                                          1
# police airplane                                                                      1
# ethnic leader: noor-ul-haq aghoundzada                                               1
# highway police patrol post                                                           1
# aabpara bus terminal                                                                 1
# residence of mayor: alber balindong                                                  1
# telephone cables for narita flight guidance system                                   1
# the sahwa al-a'zamiyah awakening council patrol                                      1
# barracks, armed police                                                               1
# vehicle, fr6 alderman                                                                1
# b.b.                                                                                 1
# guards corps base                                                                    1
# student group                                                                        1
# luxury home under construction on sarah anne court in miller place, ny               1
# faculty of medicine building                                                         1
# militia                                                                              1
# secretary general: jimmy saypan                                                      1
# vehicle of village chair: salindatu rajamuda                                         1
# james murphy, political activist, 40, catholic                                       1
# civilians near bomb blast                                                            1
# shoe trader: fozal haque                                                             1
# director: muhammad qasim                                                             1
# the vehicle of a government water resources ministry official                        1
# Name: target1, Length: 63964, dtype: int64

# %%
# target1 name mappings with at least 1000 instances
target1_names = list()

for x in ["civilians", "unknown", "vehicle", "market", "officers"]:
    if len(df[df["target1"] == x]) > 1000:
        target1_names.append(x)
# find the encoded value for each of these
for x in target1_names:
    for i, row in df.iterrows():
        if row["target1"] == x:
            print(x, row["target1_code"])
            break
# Out:
# civilians 15037
# unknown 61046
# vehicle 61386
# market 34315
# officers 39201

# %%
df[["attacktype1_txt", "attacktype1_txt_code"]].to_csv("data/attack_type.csv", index=False)

# %%
df[["targtype1_txt", "targtype1_txt_code"]].to_csv("data/target_type.csv", index=False)

# %%
features = [x for x in df.columns if x not in object_type_columns]
features
# Out:
# ['imonth',
#  'ncasualties',
#  'country_txt_code',
#  'region_txt_code',
#  'attacktype1_txt_code',
#  'targtype1_txt_code',
#  'target1_code']

# %%
df = df[features]

# %%
df.head()
# Out:
#    imonth  ncasualties country_txt_code region_txt_code attacktype1_txt_code  \
# 0       7            1               45               1                    1
# 1       0            0              114               6                    6
# 2       1            1              137               9                    1
# 3       1            0               66              11                    2
# 4       1            0              186               6                    0
#
#   targtype1_txt_code target1_code
# 0                 13        31401
# 1                  5        37488
# 2                  7        21436
# 3                  5        60318
# 4                 12        11810

# %%
df.tail()
# Out:
#         imonth  ncasualties country_txt_code region_txt_code  \
# 129917      12            2              131               8
# 129918      12            7                0               8
# 129919      12            7                0               8
# 129920      12            0              137               9
# 129921      12            0               41              10
#
#        attacktype1_txt_code targtype1_txt_code target1_code
# 129917                    0                 12        41266
# 129918                    2                 16        61386
# 129919                    2                 13        15037
# 129920                    2                 10        18163
# 129921                    6                 13        62279

# %%
df.to_csv("data/train.csv", index=False)
