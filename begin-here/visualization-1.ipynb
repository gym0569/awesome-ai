# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## Basics

# %%
plt.plot(3, 2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(3, 2, 'o') #updated the graph because of "%matplotlib notebook" interactivity

# %%
plt.figure() #create a new canvas and not update the older one
plt.plot(1, 2, 'o')
plt.axis([0, 5, 0, 5])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 5, 0, 5]

# %%
plt.plot(3, 3, 'o')

# %%
plt.plot(2, 4, 'o')

# %% [markdown]
# ## Scatter Plot

# %%
import numpy as np

# %%
x = np.arange(10)
y = np.arange(10)

# %%
plt.figure()
plt.scatter(x, y, s = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
new_x = np.array([2, 4, 7, 8])
new_y = np.array([1, 8, 3, 0])

# %%
plt.scatter(new_x, new_y, s = 100, color = 'red')

# %%
plt.figure() #new plot
plt.scatter(np.arange(0, 10), np.arange(10, 20), s = 100, color = 'orange')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(np.arange(1, 10, 2), np.arange(10, 20, 2), s = 300, color = 'green')

# %%
plt.legend(['Plot 1', 'Plot 2'])

# %% [markdown]
# ## Line Plots

# %%
plt.figure()
y1 = np.arange(1, 10)
y2 = y1 ** 2
plt.plot(y1, '-o', y2, '-o') #only y axis values no x-axis values
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
plt.axis([0, 10, 1, 100])
# Out:
# [0, 10, 1, 100]

# %%
plt.gca().fill_between(range(len(y1)), y1, y2, facecolor = 'blue', alpha = 0.40)

# %%
plt.legend(['Plot Y1', 'Plot Y2', 'Cover'])

# %% [markdown]
# ## Bar Charts

# %%
plt.figure()
x = range(len(y1))
plt.bar(x, y1, width = 0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 9 artists>

# %%
newx = []
for i in x:
    newx.append(i + 0.3)

plt.bar(newx, y2, width = 0.3, color = 'maroon')
# Out:
# <Container object of 9 artists>

# %%
plt.axis([-1, 10, 0, 100])
# Out:
# [-1, 10, 0, 100]

# %%
plt.legend(['Y1', 'Y2'])

# %%
plt.figure()
x = range(len(y1))
plt.bar(x, y1, width = 0.5, color = 'r')
plt.bar(x, y2, width = 0.5, color = 'b', bottom = y1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 9 artists>

# %%
plt.legend(['Linear Y1', 'Quad Y2'])

# %%
plt.figure()
x = range(len(y1))
plt.barh(x, y1, height = 0.5, color = 'r')
plt.barh(x, y2, height = 0.5, color = 'b', left = y1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 9 artists>

# %%
plt.legend(['Linear Y1', 'Quad Y2'])

# %%
plt.axis([0, 80, 0, 9])
# Out:
# [0, 80, 0, 9]
