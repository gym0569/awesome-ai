# %%
# fire up the packages
import pandas as pd
import numpy as np

# %%
# load the dataset
df = pd.read_csv("defaulter-dataset.csv", header=0)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df = df.set_index("Loan_ID")
df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# LP001008             1.0         Urban           Y

# %%
# feature data types
df.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
# get feature list
features = list(df.columns)

# get the list of catagorical features
categorical_features = [x for x in features if df[x].dtype == "object"]

# get numeric features
numeric_features = [x for x in features if df[x].dtype != "object"]

# %%
# check for null values in numeric features
df[numeric_features].isnull().sum()
# Out:
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# dtype: int64

# %%
# fill in the missing or null values for numeric features with mean value
for x in numeric_features:
    df[x].fillna(np.mean(df[x]), inplace=True)

# %%
# check for null values in categorical features
df[categorical_features].isnull().sum()
# Out:
# Gender           13
# Married           3
# Dependents       15
# Education         0
# Self_Employed    32
# Property_Area     0
# Loan_Status       0
# dtype: int64

# %%
# fill in the missing or null values for categorical features with highest frequency label
for x in categorical_features:
    df[x].fillna(df[x].value_counts().idxmax(), inplace=True)

# %%
# check for null values - make sure it is taken care
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0  146.412162             360.0
# LP001003             4583             1508.0  128.000000             360.0
# LP001005             3000                0.0   66.000000             360.0
# LP001006             2583             2358.0  120.000000             360.0
# LP001008             6000                0.0  141.000000             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# LP001008             1.0         Urban           Y

# %%
# let us perform normalization on the numeric features
for x in numeric_features:
    df[x] = df[x].apply(lambda s: (s - min(df[x])) / (max(df[x]) - min(df[x])))

# %%
df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002         0.070489           0.000000    0.198860           0.74359
# LP001003         0.054830           0.036192    0.172214           0.74359
# LP001005         0.035250           0.000000    0.082489           0.74359
# LP001006         0.030093           0.056592    0.160637           0.74359
# LP001008         0.072356           0.000000    0.191027           0.74359
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# LP001008             1.0         Urban           Y

# %%
# let us encode string labels to numeric values
for x in categorical_features:
    # convert the feature to categorical
    df[x] = df[x].astype("category")
    # set new feature name
    new_feature = x + "Code"
    # encode the labels to numeric values
    df[new_feature] = df[x].cat.codes
    
    # create mapping
    mappings = list()
    for i, row in df[[x, new_feature]].iterrows():
        tmp = row[x] + "->" + str(row[new_feature])
        if tmp not in mappings:
            mappings.append(tmp)
    
    # save the mapping for further use
    file = open(x+"_"+new_feature+"_Mapping.txt", mode="w")
    for m in mappings:
        file.writelines(str(m)+"\n")
    file.close()

# %%
df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002         0.070489           0.000000    0.198860           0.74359
# LP001003         0.054830           0.036192    0.172214           0.74359
# LP001005         0.035250           0.000000    0.082489           0.74359
# LP001006         0.030093           0.056592    0.160637           0.74359
# LP001008         0.072356           0.000000    0.191027           0.74359
#
#           Credit_History Property_Area Loan_Status  GenderCode  MarriedCode  \
# Loan_ID
# LP001002             1.0         Urban           Y           1            0
# LP001003             1.0         Rural           N           1            1
# LP001005             1.0         Urban           Y           1            1
# LP001006             1.0         Urban           Y           1            1
# LP001008             1.0         Urban           Y           1            0
#
#           DependentsCode  EducationCode  Self_EmployedCode  Property_AreaCode  \
# Loan_ID
# LP001002               0              0                  0                  2
# LP001003               1              0                  0                  0
# LP001005               0              0                  1                  2
# LP001006               0              1                  0                  2
# LP001008               0              0                  0                  2
#
#           Loan_StatusCode
# Loan_ID
# LP001002                1
# LP001003                0
# LP001005                1
# LP001006                1
# LP001008                1

# %%
# remove old string label categorical features
for x in categorical_features:
    del df[x]
df.head()
# Out:
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002         0.070489           0.000000    0.198860           0.74359
# LP001003         0.054830           0.036192    0.172214           0.74359
# LP001005         0.035250           0.000000    0.082489           0.74359
# LP001006         0.030093           0.056592    0.160637           0.74359
# LP001008         0.072356           0.000000    0.191027           0.74359
#
#           Credit_History  GenderCode  MarriedCode  DependentsCode  \
# Loan_ID
# LP001002             1.0           1            0               0
# LP001003             1.0           1            1               1
# LP001005             1.0           1            1               0
# LP001006             1.0           1            1               0
# LP001008             1.0           1            0               0
#
#           EducationCode  Self_EmployedCode  Property_AreaCode  Loan_StatusCode
# Loan_ID
# LP001002              0                  0                  2                1
# LP001003              0                  0                  0                0
# LP001005              0                  1                  2                1
# LP001006              1                  0                  2                1
# LP001008              0                  0                  2                1

# %%
# save the cleaned and preprocessed data for modelling
df.to_csv("train.csv")
